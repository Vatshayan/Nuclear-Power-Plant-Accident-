# %%
#Developed by Shivam Vatshayan. Contact for Job, Internhip, Research Position and Project work
#Shoot me at Vatshayan007@gmail.com Now!!

# %%
# Importing required Packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv("Nuclear.csv")

# %%
train.head(10)
# Out:
#          Date                                 Location  \
# 0   4/26/1986                            Kiev, Ukraine
# 1   3/11/2011              Fukushima Prefecture, Japan
# 2   12/8/1995                           Tsuruga, Japan
# 3   3/28/1979  Middletown, Pennsylvania, United States
# 4   9/11/1957                         Rocky Flats, USA
# 5   3/25/1955                           Sellafield, UK
# 6    1/1/1977                          Beloyarsk, USSR
# 7   7/14/1955                           Sellafield, UK
# 8  10/12/1969                           Sellafield, UK
# 9    3/9/1985           Athens, Alabama, United States
#
#    Cost (millions 2013US$)  INES  Smyth Magnitude Region  \
# 0                 259336.0   7.0              8.0     EE
# 1                 166089.0   7.0              7.5      A
# 2                  15500.0   NaN              NaN      A
# 3                  10910.0   5.0              7.9    NaN
# 4                   8189.0   5.0              5.2    NaN
# ...

# %%
train.tail(10)
# Out:
#            Date                              Location  \
# 206  11/19/2003                      La Hague, France
# 207  06/10/2009                     Cadarache, France
# 208  08/27/2008                      Trhange, Belgium
# 209  11/22/2002                      Trhange, Belgium
# 210  05/12/1988                        Civaux, France
# 211  11/03/1997             Ibaraki Prefecture, Japan
# 212  05/15/1996  Morris, Grundy County, Illinois, USA
# 213  03/11/1978              Pinawa, Manitoba, Canada
# 214  09/25/1990                     Pickering, Canada
# 215  08/02/1992                     Pickering, Canada
#
#      Cost (millions 2013US$)  INES  Smyth Magnitude Region  \
# 206                      NaN   2.0              NaN     WE
# 207                      NaN   2.0              NaN     WE
# 208                      NaN   1.0              NaN     WE
# 209                      NaN   2.0              NaN     WE
# 210                      NaN   2.0              NaN    NaN
# ...

# %%
train.dtypes
# Out:
# Date                        object
# Location                    object
# Cost (millions 2013US$)    float64
# INES                       float64
# Smyth Magnitude            float64
# Region                      object
# Description                 object
# Fatalities                   int64
# dtype: object

# %%
train.shape
# Out:
# (216, 8)

# %%
plt.figure(10)
plt.subplot(221)
train['Date'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Date')

# %%
plt.figure(10)
plt.subplot(221)
train['Location'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Location')

# %%
plt.figure(10)
plt.subplot(221)
train['INES'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'INES')

# %%
plt.figure(10)
plt.subplot(221)
train['Cost (millions 2013US$)'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Cost (millions 2013US$)')

# %%
train.dtypes
# Out:
# Date                        object
# Location                    object
# Cost (millions 2013US$)    float64
# INES                       float64
# Smyth Magnitude            float64
# Region                      object
# Description                 object
# Fatalities                   int64
# dtype: object

# %%
plt.figure(10)
plt.subplot(221)
train['Region'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Region')

# %%
plt.figure(10)
plt.subplot(221)
train['Description'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Description')

# %%
plt.figure(10)
plt.subplot(221)
train['Fatalities'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Fatalities')

# %%
plt.figure(10)
plt.subplot(221)
train['Smyth Magnitude'].value_counts(normalize=True).plot.bar(figsize=(50,30), title= 'Smyth Magnitude')

# %%
# Print correlation matrix (heat map)
matrix = train.corr()
f, ax = plt.subplots(figsize=(10,7))
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu");

# %%
#Will Add More In Few Days !! Keep Following.
